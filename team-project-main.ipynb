# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('loan.csv')

# %%
pd.set_option('display.max_info_columns', 200) # Makes sure all values are displayed

# %%
df['loan_status'].value_counts()
# Out:
# Current               40902
# Fully Paid              860
# In Grace Period         111
# Late (31-120 days)       60
# Late (16-30 days)        53
# Charged Off               3
# Name: loan_status, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41989 entries, 0 to 41988
# Data columns (total 145 columns):
#  #    Column                                      Non-Null Count  Dtype
# ---   ------                                      --------------  -----
#  0    id                                          0 non-null      float64
#  1    member_id                                   0 non-null      float64
#  2    loan_amnt                                   41989 non-null  int64
#  3    funded_amnt                                 41989 non-null  int64
#  4    funded_amnt_inv                             41989 non-null  int64
#  5    term                                        41989 non-null  object
#  6    int_rate                                    41989 non-null  float64
#  7    installment                                 41989 non-null  float64
#  8    grade                                       41989 non-null  object
# ...
